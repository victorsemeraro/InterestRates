# %% [markdown]
# # <center> <u> Interest Rate Dynamics </u> </center>

# %%
import requests
import numpy as np
import pandas as pd 

from numba import jit, prange
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt 

from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## <center> Set Seaborn Theme </center>

# %%
sns.set_theme(
    style = "darkgrid",
    palette = "bright",
)

plt.rc('figure', figsize = (10, 5))

# %% [markdown]
# ## <center> Parse Treasury Data </center>

# %%
years = [2021, 2022, 2023]
URL = [
    "https://home.treasury.gov/resource-center/data-chart-center/interest-rates/daily-treasury-rates.csv/",
    "/all?field_tdr_date_value=",
    "&type=daily_treasury_yield_curve&page&_format=csv",
      ]

# %%
df_list = []

for y in years:
    tmp_df = pd.read_csv(URL[0] + str(y) + URL[1] + str(y) + URL[2])
    df_list.append(tmp_df.iloc[::-1])

# %%
df = pd.concat(df_list, ignore_index = True)

# %%
df.head()
# Out:
#          Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 0  01/04/2021  0.09  0.09  0.09  0.09  0.10  0.11  0.16  0.36  0.64   0.93
# 1  01/05/2021  0.08  0.09  0.09  0.09  0.10  0.13  0.17  0.38  0.66   0.96
# 2  01/06/2021  0.09  0.09  0.09  0.09  0.11  0.14  0.20  0.43  0.74   1.04
# 3  01/07/2021  0.09  0.09  0.09  0.09  0.11  0.14  0.22  0.46  0.78   1.08
# 4  01/08/2021  0.08  0.08  0.08  0.09  0.10  0.14  0.24  0.49  0.81   1.13
#
#    20 Yr  30 Yr  4 Mo
# 0   1.46   1.66   NaN
# 1   1.49   1.70   NaN
# 2   1.60   1.81   NaN
# 3   1.64   1.85   NaN
# 4   1.67   1.87   NaN

# %%
df.tail()
# Out:
#            Date  1 Mo  2 Mo  3 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# 687  09/29/2023  5.55  5.60  5.55  5.53  5.46  5.03  4.80  4.60  4.61   4.59
# 688  10/02/2023  5.56  5.60  5.62  5.58  5.49  5.12  4.88  4.72  4.73   4.69
# 689  10/03/2023  5.55  5.60  5.62  5.58  5.49  5.15  4.95  4.80  4.84   4.81
# 690  10/04/2023  5.56  5.58  5.61  5.57  5.42  5.05  4.85  4.72  4.75   4.73
# 691  10/05/2023  5.57  5.59  5.61  5.56  5.39  5.03  4.82  4.68  4.73   4.72
#
#      20 Yr  30 Yr  4 Mo
# 687   4.92   4.73  5.61
# 688   5.00   4.81  5.62
# 689   5.13   4.95  5.62
# 690   5.05   4.87  5.62
# 691   5.06   4.89  5.62

# %%
three_month_rate = df["3 Mo"].to_numpy() / 100
six_month_rate = df["6 Mo"].to_numpy() / 100
one_year_rate = df["1 Yr"].to_numpy() / 100

# %%
ax = sns.lineplot(
    three_month_rate,
    label = "Three Month",
)

sns.lineplot(
    six_month_rate,
    label = "Six Month",
)

sns.lineplot(
    one_year_rate,
    label = "One Year",
)

ax.set(
    title = "US Treasury Bills Yield"
)

plt.show()

# %%
two_year_rate = df["2 Yr"].to_numpy() / 100
five_year_rate = df["5 Yr"].to_numpy() / 100
seven_year_rate = df["7 Yr"].to_numpy() / 100
ten_year_rate = df["10 Yr"].to_numpy() / 100

# %%
ax = sns.lineplot(
    two_year_rate,
    label = "Two Year",
)

sns.lineplot(
    five_year_rate,
    label = "Five Year",
)

sns.lineplot(
    seven_year_rate,
    label = "Seven Year",
)

sns.lineplot(
    ten_year_rate,
    label = "Ten Year",
)

ax.set(
    title = "US Treasury Notes Yield"
)

plt.show()

# %%
twenty_year_rate = df["20 Yr"].to_numpy() / 100
thirty_year_rate = df["30 Yr"].to_numpy() / 100

# %%
ax = sns.lineplot(
    twenty_year_rate,
    label = "20 Year",
)

sns.lineplot(
    thirty_year_rate,
    label = "30 Year",
)

ax.set(
    title = "US Treasury Bond Yields"
)

plt.plot()
# Out:
# []

# %% [markdown]
# ## <center> Three Month Treasury Bill </center>
#
# ## <center> $ P = \frac{FV}{(1 + \frac{r}{4})} $ </center>

# %%
@jit(nopython = True)
def compute_three_month_treasury_bill_price(bond_yields):
    """
    
    """
    
    FV = 100
    L = len(bond_yields)
    P = np.copy(bond_yields)
    
    for i in range(L):
        P[i] = FV / (1 + (bond_yields[i] / 4))
    
    return P

# %%
three_month_prices = compute_three_month_treasury_bill_price(three_month_rate)

# %% [markdown]
# ## <center> Six Month Treasury Bill </center>
#
# ## <center> $ P = \frac{FV}{(1 + \frac{r}{2})} $ </center>

# %%
@jit(nopython = True)
def compute_six_month_treasury_bill_price(bond_yields):
    """
    
    """
    
    FV = 100
    L = len(bond_yields)
    P = np.copy(bond_yields)
    
    for i in range(L):
        P[i] = FV / (1 + (bond_yields[i] / 2))
    
    return P

# %%
six_month_prices = compute_six_month_treasury_bill_price(six_month_rate)

# %% [markdown]
# ## <center> One Year Treasury Bill </center>
#
# ## <center> $ P = \frac{C}{(1 + \frac{r}{2})} + \frac{FV}{(1 + \frac{r}{2})^{2}} $ </center>

# %%
@jit(nopython = True)
def compute_one_year_treasury_bill_price(bond_yields):
    """
    
    """
    
    FV = 100
    L = len(bond_yields)
    P = np.copy(bond_yields)
    
    for i in range(L):
        coupon_payment = (FV * (1 + bond_yields[i] / 2)) / (1 + (bond_yields[i] / 2))
        final_payment = FV / (1 + (bond_yields[i] / 2))**2
        P[i] = (coupon_payment + final_payment) / 2
    
    return P

# %%
one_year_prices = compute_one_year_treasury_bill_price(one_year_rate)

# %%
ax = sns.lineplot(
    three_month_prices,
    label = "Three Month Price"
)

sns.lineplot(
    six_month_prices,
    label = "Six Month Price"
)

sns.lineplot(
    one_year_prices,
    label = "One Year Price"
)

ax.set(
    title = "US Treasury Bill Price",
    xlabel = "Days",
    ylabel = "Price",
)

plt.show()

# %% [markdown]
# ## <center> Ten Year Note </center>
#
# ## <center> $ P = \sum_{i=1}^{N} \frac{C_{i}}{(1 + \frac{r}{2})^{N}} + \frac{FV}{(1 + \frac{r}{2})^{N}}$ </center>

# %%
@jit(nopython = True)
def compute_treasury_note_price(bond_yields, years):
    """
    
    """
    
    FV = 100
    N = 2 * years
    L = len(bond_yields)
    P = np.copy(bond_yields)
    
    for i in range(L):
        
        tmp = np.zeros(N)
        
        for j in range(1, N):
            tmp[j-1] = (FV * (1 + bond_yields[i] / 2)) / (1 + (bond_yields[i] / 2))**j
            
        tmp[-1] = FV / (1 + (bond_yields[i] / 2))**N
        P[i] = np.sum(tmp) / N
    
    return P

# %%
two_year_note_prices = compute_treasury_note_price(two_year_rate, 2)
five_year_note_prices = compute_treasury_note_price(five_year_rate, 5)
seven_year_note_prices = compute_treasury_note_price(seven_year_rate, 7)
ten_year_note_prices = compute_treasury_note_price(ten_year_rate, 10)

# %%
ax = sns.lineplot(
    two_year_note_prices,
    label = "Two Year",
)

sns.lineplot(
    five_year_note_prices,
    label = "Five Year",
)

sns.lineplot(
    seven_year_note_prices,
    label = "Seven Year",
)

sns.lineplot(
    ten_year_note_prices,
    label = "Ten Year",
)

ax.set(
    title = "US Treasury Note Price",
    xlabel = "Days",
    ylabel = "Price",
)

plt.show()

# %%
twenty_year_note_prices = compute_treasury_note_price(twenty_year_rate, 20)
thirty_year_note_prices = compute_treasury_note_price(thirty_year_rate, 30)

# %%
ax = sns.lineplot(
    twenty_year_note_prices,
    label = "Twenty Year",
)

sns.lineplot(
    thirty_year_note_prices,
    label = "Thirty Year",
)

ax.set(
    title = "US Treasury Bond Price",
    xlabel = "Days",
    ylabel = "Price",
)

plt.show()

# %% [markdown]
# ## <center> Three Month Duration </center>
#
# ## <center> $ \frac{\partial}{\partial r} = -\frac{FV}{(1 + \frac{r}{4})^{2}} $ </center>

# %%
@jit(nopython = True)
def compute_three_month_duration(bond_yields, bond_prices):
    """
    
    """
    
    FV = 100
    N = len(bond_yields)
    D = np.copy(bond_yields)
    
    for i in range(N):
        D[i] = (1 / bond_prices[i]) * -FV / (1 + (bond_yields[i] / 2))**2
    
    return D

# %% [markdown]
# ## <center> Six Month Duration </center>
#
# ## <center> $ \frac{\partial}{\partial r} = -\frac{FV}{(1 + \frac{r}{2})^{2}} $ </center>

# %%
@jit(nopython = True)
def compute_six_month_duration(bond_yields, bond_prices):
    """
    
    """
    
    FV = 100
    N = len(bond_yields)
    D = np.copy(bond_yields)
    
    for i in range(N):
        D[i] = (1 / bond_prices[i]) * -FV / (1 + (bond_yields[i] / 2))**2
    
    return D

# %% [markdown]
# ## <center> One Year Duration </center>
#
# ## <center> $ \frac{\partial}{\partial r} = -\frac{C}{(1 + \frac{r}{2})^{2}} - \frac{FV}{(1 + \frac{r}{2})^{3}} $ </center>

# %%
@jit(nopython = True)
def compute_one_year_duration(bond_yields, bond_prices):
    """
    
    """
    
    FV = 100
    N = len(bond_yields)
    D = np.copy(bond_yields)
    
    for i in range(N):
        coupon_payment = -(FV * (1 + bond_yields[i] / 2)) / (1 + bond_yields[i] / 2)**2
        final_payment = -(FV / (1 + bond_yields[i] / 2)**3)
        D[i] = (1 / bond_prices[i]) * (coupon_payment + final_payment)
    
    return D

# %%
three_month_duration = compute_three_month_duration(three_month_rate, three_month_prices)
six_month_duration = compute_six_month_duration(six_month_rate, six_month_prices)
one_year_duration = compute_one_year_duration(one_year_rate, one_year_prices)

# %%
ax = sns.lineplot(
    three_month_duration,
    label = "Three Month"
)

sns.lineplot(
    six_month_duration,
    label = "Six Month"
)

sns.lineplot(
    one_year_duration,
    label = "One Year"
)


ax.set(
    title = "Treasury Bill Duration"
)

plt.show()

# %%
@jit(nopython = True)
def compute_duration(bond_yields, bond_prices):
    """
    
    """
    
    FV = 100
    N = len(bond_yields)
    D = np.copy(bond_yields)
    
    for i in range(N):
        D[i] = (1 / bond_prices[i]) * -FV / (1 + bond_yields[i])**2
    
    return D

# %% [markdown]
# ## <center> Convexity </center>
#
# ## <center> $ \frac{\partial}{\partial r^{2}} = 2 \cdot \frac{FV}{(1 + r)^{3}}$ </center>

# %%
@jit(nopython = True)
def compute_convexity(bond_yields, bond_prices):
    """
    
    """
    
    FV = 100
    N = len(bond_yields)
    D = np.copy(bond_yields)
    
    for i in range(N):
        D[i] = (2 / bond_prices[i]) * (FV / (1 + bond_yields[i])**3)
    
    return D

# %%
convexity = compute_convexity(interest_rate, prices)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 convexity = compute_convexity(interest_rate, prices)
#
# NameError: name 'interest_rate' is not defined

# %%
ax = sns.lineplot(
    convexity
)

ax.set(
    title = "Treasury Bond Convexity"
)

plt.show()
